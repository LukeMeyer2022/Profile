# %%
# Import Packages and Import Raw Data
import pandas as pd

# %%
data_path = "metabolic_syndrome.csv"
df = pd.read_csv(data_path)
df
# Out:
#        seqn  age     sex  marital  income         race  waistcirc   bmi  \
# 0     62161   22    Male   Single  8200.0        White       81.0  23.3
# 1     62164   44  Female  Married  4500.0        White       80.1  23.2
# 2     62169   21    Male   Single   800.0        Asian       69.6  20.1
# 3     62172   43  Female   Single  2000.0        Black      120.4  33.3
# 4     62177   51    Male  Married     NaN        Asian       81.1  20.1
# ...     ...  ...     ...      ...     ...          ...        ...   ...
# 2396  71901   48  Female  Married  1000.0        Other        NaN  59.7
# 2397  71904   30  Female   Single  2000.0        Asian        NaN  18.0
# 2398  71909   28    Male   Single   800.0  MexAmerican      100.8  29.4
# 2399  71911   27    Male  Married  8200.0  MexAmerican      106.6  31.3
# 2400  71915   60    Male   Single  6200.0        White      106.6  27.5
#
#       albuminuria  uralbcr  uricacid  bloodglucose  hdl  triglycerides  \
# ...

# %%
import pandas as pd

def describe_data(df, group_col, output_filename):
    # Grouping the DataFrame by the specified column
    grouped = df.groupby(group_col)
    
    # Applying the statistical summary to each group
    description = grouped.describe().loc[:, (slice(None), ['mean', 'std', 'min', '25%', '50%', '75%', 'max'])]
    
    # Save the DataFrame to a CSV file
    description.to_csv(output_filename)

    return description


group_col = "metabolicsyndrome" 
output_filename = 'stratified_summary_data.csv'
description = describe_data(df, group_col, output_filename)
description
# Out:
#                            seqn                                          \
#                            mean          std      min      25%      50%
# metabolicsyndrome
# MetSyn             67075.138686  2775.710621  62199.0  64745.5  67118.0
# No MetSyn          67007.526916  2848.756780  62161.0  64479.5  67058.0
#
#                                             age                   ...   hdl  \
#                         75%      max       mean        std   min  ...   50%
# metabolicsyndrome                                                 ...
# MetSyn             69432.25  71915.0  54.766423  16.019520  20.0  ...  44.0
# No MetSyn          69517.00  71909.0  45.529449  17.610585  20.0  ...  55.0
#
#                                triglycerides                                  \
#                     75%    max          mean         std   min    25%    50%
# metabolicsyndrome
# MetSyn             51.0   98.0    184.558394  129.071106  31.0  108.0  157.5
# ...
